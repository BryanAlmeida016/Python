# %% [markdown]
# <a href="https://colab.research.google.com/github/BryanAlmeida016/Python/blob/main/2_ExemploAnalisedasInscricoes.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Análise de Dados Simples - Inscrições do Curso

# %% [markdown]
# ### Após a Aula introdutória vamos ver como colher algumas informações Simples Usando Python

# %%
import pandas as pd #Biblioteca responsável para fazer a leitura e impressão de bases de dados

# %% [markdown]
# ### Veja neste link como armazenar uma planilha excel no Github para usar como base de dados no COLAB

# %%
url = 'https://github.com/profcintiapinho/laboratorio_ia/blob/main/respostasalunos.xlsx?raw=true' #pega o caminho do arquivo excel no github
planilha = "respostas" #identifica a planilha que está os dados
base = pd.read_excel(url,planilha) #pega o caminho e a planilha exata e armazena na variável

# %%
base.head()
# Out:
#                                  Turma interesse computador  \
# 0      Novo Tec - Administração(Tarde)     Noite        Sim
# 1                Contabilidade - Noite     Tarde        Sim
# 2                Contabilidade - Noite     Tarde        Sim
# 3  Novo Tec - Recursos Humanos (Manhã)     Noite        Sim
# 4                Contabilidade - Noite     Tarde        Sim
#
#                                            motivacao
# 0  Quero estar mais liga e aprender muito mais  s...
# 1  conseguir automatizar alguns processos no meu ...
# 2  Obter um pouco de conhecimento nessa área, a q...
# 3  Porque o python é uma linguagens de programaçã...
# 4                quero aprimorar meus conhecimentos

# %%
import matplotlib.pyplot as plt #biblioteca para gerar gráficos
import seaborn as sns #biblioteca para visualizar gráficos

# %%
plt.subplots(figsize=(30, 10))
sns.countplot(x=base["Turma"]);

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.countplot(base['computador'], color='#00BFFF');
plt.title('Alunos possuem computadores?')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-6-bdaa5a90c905> in <cell line: 3>()
#       1 import seaborn as sns
#       2 import matplotlib.pyplot as plt
# ----> 3 sns.countplot(base['computador'], color='#00BFFF');
#       4 plt.title('Alunos possuem computadores?')
#
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py in countplot(data, x, y, hue, order, hue_order, orient, color, palette, saturation, width, dodge, ax, **kwargs)
#    2941         raise ValueError("Cannot pass values for both `x` and `y`")
#    2942
# -> 2943     plotter = _CountPlotter(
#    2944         x, y, hue, data, order, hue_order,
#    2945         estimator, errorbar, n_boot, units, seed,
#
# ...

# %%
base['interesse'].value_counts()
# Out:
# Tarde    31
# Noite    30
# Name: interesse, dtype: int64

# %%
tarde = base.interesse.value_counts()['Tarde']
noite = base.interesse.value_counts()['Noite']

# %%
x = ["Tarde", "Noite"]
y = [tarde, noite]

# %%
plt.barh(x, y)
plt.yticks(rotation=45)
plt.title('Período do Curso')
plt.show()

# %%
cores = ['#4169E1','#00BFFF','#00008B']
plt.pie(y, labels=x, autopct='%1.1f%%', colors = cores)
plt.show()

# %%
import spacy
import re

# %%
# !python -m spacy download pt_core_news_sm
# Out:
# 2023-09-14 13:55:20.087246: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.0/13.0 MB 25.9 MB/s eta 0:00:00
# ...
# ✔ Download and installation successful
# You can now load the package via spacy.load('pt_core_news_sm')

# %%
pln = spacy.load('pt_core_news_sm')

# %%
from spacy.lang.pt.stop_words import STOP_WORDS
stop_words = STOP_WORDS

# %% [markdown]
# #Contador de quantia de palavras dentro do **Stop Words**
# *Stop Words* -> Palavras que não dão sentido ao texto, servem como conexão de elementos ortográficos...

# %%
len(stop_words)
# Out:
# 416

# %%
"caminho" in stop_words
# Out:
# True

# %%
import string
pontuacoes = string.punctuation
pontuacoes
# Out:
# '!"#$%&\'()*+,-./:;<=>?@[\\]^_`{|}~'

# %%
def preprocessamento(text):
    result = []
    pos_tag = ['ADJ', 'NOUN', 'VERB', 'PROPN'] # escolhendo apenas adjetivos, substantivos e verbos , 'VERB'
    texto = re.sub(u'[^a-zA-Z0-9áéíóúÁÉÍÓÚâêîôÂÊÎÔãõÃÕçÇ: ]', '', text )
    doc = pln(texto.lower()) # Transformando em minúsculo
    for token in doc:
        # 3
        if(token.text in stop_words or token.text in pontuacoes):
            continue
        # 4
        if(token.pos_ in pos_tag):
            result.append(token.text)

        texto = ' '.join([str(elemento) for elemento in result if not elemento.isdigit()])


    #return result # 5
    return texto # 5

# %%
base.motivacao=base.motivacao.astype(str)
base['limpa'] = base['motivacao'].apply(preprocessamento)

# %%
base
# Out:
#                                   Turma interesse computador  \
# 0       Novo Tec - Administração(Tarde)     Noite        Sim
# 1                 Contabilidade - Noite     Tarde        Sim
# 2                 Contabilidade - Noite     Tarde        Sim
# 3   Novo Tec - Recursos Humanos (Manhã)     Noite        Sim
# 4                 Contabilidade - Noite     Tarde        Sim
# ..                                  ...       ...        ...
# 56                    Logistica - Noite     Tarde        não
# 57                    Logistica - Noite     Tarde        não
# 58       Novo Tec - Informática (Manhã)     Tarde        Sim
# 59       Novo Tec - Informática (Manhã)     Noite        Sim
# 60       Novo Tec - Informática (Manhã)     Noite        Sim
#
#                                             motivacao  \
# 0   Quero estar mais liga e aprender muito mais  s...
# 1   conseguir automatizar alguns processos no meu ...
# 2   Obter um pouco de conhecimento nessa área, a q...
# ...

# %%
motivo = base['limpa'].values
juntandotudo = ''
for sentimento in motivo:
  juntandotudo += sentimento+" "

# %%
juntandotudo
# Out:
# 'liga aprender tecnologia conseguir automatizar processos trabalho obter conhecimento solicitado mercado trabalho python linguagens programação fácil executar projetos tamanhos sabendo python aprimorar conhecimentos aprimorar conhecimentos venho interessando tecnologia conhecimento adquirir conhecimentos agregar conhecimentos currículo achei interessante curso melhorar conhecimento python interessei gosto programação estudei python conhecimento indicação documentário coded bias desenvolvi interesse expandir conhecimentos futuro melhor incrementar currículo interesse interesse explorar áreas informática estudei python motivos conhecer mexe funciona adquirir conhecimento busco melhor capacitação ingressar mercado trabalho interesse tema curso gosto aprender coisas acredito oportunidade aparece agarrada tema curso desperta interesse experiência area interesse aprender tecnologias atuais ampliar conhecimento amo áreae decidindo aprender fundamental aprender coisas tornar profissional qua
# ...

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt
plt.figure(figsize=(20,20))
plt.axis('off')
plt.imshow(WordCloud().generate(juntandotudo))

# %%
teste='''Obra de Arte, O Jogo entre jogos, Jogo Eterno, Deus Divinal. Esse jogo beira a perfeição, só nao ganha 20 mil estrelas por que a versão de PC tem problemas técnicos inadimissiveis e nos consoles de "nova geração" o modo qualidade tem uma queda de frames sinistra e no meu Xbox Series X ele ate crashou uma vez na luta contra o maldito do Radham. Mas esse jogo vale, vale cada centavo investido nele (mesmo que 300 reais doam demais) e cada minuto de dedicação. Não tem coisa mais divertida que sair rodando feito um doido explorando cada milimetro desse mapa maravilhoso, cheio de coisa pra se achar, interagir e NPCs pra conversar. Pulo adicionou mais um elemento de estrategia, tanto pro PVP quato PVE e exploração, e o pulo duplo do torrent, no nosso amigo de chifre é a melhor feature ever! Uma pena só ano haver combate montado no PVP, espero que Tio Hidetaka e sua equipe de genios ajustem isso um dia, mas compreendo as razões de nao haver. O jogo é lindo, a direção de arte se superou mais uma vez, o nivel de atenção aos detalhes é imenso, jogos da From são Bonitos por causa disso, não por causa de Ray Tracing ou Fidelidade Grafica. Inimigos variados e com designs intresantes, a bizarrice de alguns inimigos impressiona, ali nao tem só influencias de Bersek não, tem muita coisa meio Junji Ito. Serio esse jogo é MARAVILHOSO. É dificil? Sim, mas nada impossivel e com criatividade e muita safadeza você aprende a queijar a maior parte dos bosses e adversarios no PVP, seja subindo onde eles nao podem subir, apelando pra alguma ashe of war apelona, se valendo dos arcos ou de magias que são insanamente roubadas. O craft desse jogo é util e adiciona muito ao gameplay, é divertido sair caçando recursos pra craftar lanças, bombas, buffs temporarios e itens que adicionam dano elemental, poison/bleed que é a podridão vermelha a sua arma. Serio, vão jogar, tem tenta coisa nesse jogo que falar sobre ele dá uma tese de doutorado, vai jogar e descubra, explore, aprenda e jogue, jogue muito, esse jogo dá 200 hrs de gameplay facil, e sem enjoar.'''

# %%
teste = base['limpa'].values
arrumando = ''
for sentimento in motivo:
  juntandotudo += sentimento+" "

# %%
teste= preprocessamente(teste)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-33-16bcd05a89bc> in <cell line: 1>()
# ----> 1 teste= preprocessamente(teste)
#
# NameError: name 'preprocessamente' is not defined

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt
plt.figure(figsize=(20,20))
plt.axis('off')
plt.imshow(WordCloud().generate(teste))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-30-c29a3d5eb928> in <cell line: 5>()
#       3 plt.figure(figsize=(20,20))
#       4 plt.axis('off')
# ----> 5 plt.imshow(WordCloud().generate(teste))
#
# /usr/local/lib/python3.10/dist-packages/wordcloud/wordcloud.py in generate(self, text)
#     637         self
#     638         """
# --> 639         return self.generate_from_text(text)
#     640
#     641     def _check_generated(self):
#
# /usr/local/lib/python3.10/dist-packages/wordcloud/wordcloud.py in generate_from_text(self, text)
#     618         self
#     619         """
# --> 620         words = self.process_text(text)
#     621         self.generate_from_frequencies(words)
#     622         return self
#
# /usr/local/lib/python3.10/dist-packages/wordcloud/wordcloud.py in process_text(self, text)
# ...
